# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Loan_approval.csv')

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0         29900000          12           778                    2400000
# 1         12200000           8           417                    2700000
# 2         29700000          20           506                    7100000
# 3         30700000           8           467                   18200000
# 4         24200000          20           382                   12400000
# ...            ...         ...           ...                        ...
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                     17600000              22700000            8000000
# 1                      2200000               8800000            3300000
# 2                      4500000              33300000           12800000
# 3                      3300000              23300000            7900000
# 4                      8200000              29400000            5000000
# ...                        ...                   ...                ...
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 0        Approved
# 1        Rejected
# 2        Rejected
# 3        Rejected
# 4        Rejected
# ...           ...
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved
#
# [4269 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
columns_to_drop = ['loan_id','residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']

df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score loan_status
# 0        29900000         12          778    Approved
# 1        12200000          8          417    Rejected
# 2        29700000         20          506    Rejected
# 3        30700000          8          467    Rejected
# 4        24200000         20          382    Rejected
# ...           ...        ...          ...         ...
# 4264      2300000         12          317    Rejected
# 4265     11300000         20          559    Approved
# 4266     23900000         18          457    Rejected
# 4267     12800000          8          780    Approved
# 4268     29700000         10          607    Approved
#
# [4269 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   no_of_dependents  4269 non-null   int64
#  1   education         4269 non-null   object
#  2   self_employed     4269 non-null   object
#  3   income_annum      4269 non-null   int64
#  4   loan_amount       4269 non-null   int64
#  5   loan_term         4269 non-null   int64
#  6   cibil_score       4269 non-null   int64
#  7   loan_status       4269 non-null   object
# dtypes: int64(5), object(3)
# memory usage: 266.9+ KB

# %%
df_encode = pd.get_dummies(df, dtype = int)

# %%
df_encode
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       education_ Graduate  education_ Not Graduate  self_employed_ No  \
# 0                       1                        0                  1
# 1                       0                        1                  0
# 2                       1                        0                  1
# 3                       1                        0                  1
# 4                       0                        1                  0
# ...                   ...                      ...                ...
# 4264                    1                        0                  0
# 4265                    0                        1                  0
# 4266                    0                        1                  1
# 4267                    0                        1                  1
# 4268                    1                        0                  1
#
#       self_employed_ Yes  loan_status_ Approved  loan_status_ Rejected
# 0                      0                      1                      0
# 1                      1                      0                      1
# 2                      0                      0                      1
# 3                      0                      0                      1
# 4                      1                      0                      1
# ...                  ...                    ...                    ...
# 4264                   1                      0                      1
# 4265                   1                      1                      0
# 4266                   0                      0                      1
# 4267                   0                      1                      0
# 4268                   0                      1                      0
#
# [4269 rows x 11 columns]

# %%
df_final = df_encode.drop(['loan_status_ Rejected', 'self_employed_ No', 'education_ Not Graduate'], axis = 1)

# %%
df_final
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       education_ Graduate  self_employed_ Yes  loan_status_ Approved
# 0                       1                   0                      1
# 1                       0                   1                      0
# 2                       1                   0                      0
# 3                       1                   0                      0
# 4                       0                   1                      0
# ...                   ...                 ...                    ...
# 4264                    1                   1                      0
# 4265                    0                   1                      1
# 4266                    0                   0                      0
# 4267                    0                   0                      1
# 4268                    1                   0                      1
#
# [4269 rows x 8 columns]

# %%
df_final.corr()
# Out:
#                        no_of_dependents  income_annum  loan_amount  loan_term  \
# no_of_dependents               1.000000      0.007266    -0.003366  -0.020111
# income_annum                   0.007266      1.000000     0.927470   0.011488
# loan_amount                   -0.003366      0.927470     1.000000   0.008437
# loan_term                     -0.020111      0.011488     0.008437   1.000000
# cibil_score                   -0.009998     -0.023034    -0.017035   0.007810
# education_ Graduate            0.002697      0.011625     0.010631  -0.008417
# self_employed_ Yes             0.000765      0.002368     0.001450   0.004107
# loan_status_ Approved         -0.018114     -0.015189     0.016150  -0.113036
#
#                        cibil_score  education_ Graduate  self_employed_ Yes  \
# no_of_dependents         -0.009998             0.002697            0.000765
# income_annum             -0.023034             0.011625            0.002368
# loan_amount              -0.017035             0.010631            0.001450
# loan_term                 0.007810            -0.008417            0.004107
# cibil_score               1.000000            -0.004649           -0.004866
# education_ Graduate      -0.004649             1.000000           -0.023224
# self_employed_ Yes       -0.004866            -0.023224            1.000000
# loan_status_ Approved     0.770518             0.004918            0.000345
#
#                        loan_status_ Approved
# no_of_dependents                   -0.018114
# income_annum                       -0.015189
# loan_amount                         0.016150
# loan_term                          -0.113036
# cibil_score                         0.770518
# education_ Graduate                 0.004918
# self_employed_ Yes                  0.000345
# loan_status_ Approved               1.000000

# %%
X = df_final.iloc[:, :-1]
y = df_final.iloc[:,-1]

# %%
X
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       education_ Graduate  self_employed_ Yes
# 0                       1                   0
# 1                       0                   1
# 2                       1                   0
# 3                       1                   0
# 4                       0                   1
# ...                   ...                 ...
# 4264                    1                   1
# 4265                    0                   1
# 4266                    0                   0
# 4267                    0                   0
# 4268                    1                   0
#
# [4269 rows x 7 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status_ Approved, Length: 4269, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scale  = MinMaxScaler()

# %%
X_not_scale = X[['no_of_dependents','cibil_score','loan_term','education_ Graduate','self_employed_ Yes']]

# %%
X_scaled = scale.fit_transform(X[['income_annum'	,'loan_amount']])

# %%
X_scaled = pd.DataFrame(X_scaled, columns = [['income_annum'	,'loan_amount']])

# %%
X_scaled
# Out:
#      income_annum loan_amount
# 0        0.969072    0.755102
# 1        0.402062    0.303571
# 2        0.917526    0.750000
# 3        0.824742    0.775510
# 4        0.989691    0.609694
# ...           ...         ...
# 4264     0.082474    0.051020
# 4265     0.319588    0.280612
# 4266     0.649485    0.602041
# 4267     0.402062    0.318878
# 4268     0.927835    0.750000
#
# [4269 rows x 2 columns]

# %%
X_scaled.columns = ['income', 'loan_amt']

# %%
frames = [X_not_scale,X_scaled]

# %%
X_new = pd.concat(frames, axis = 1)

# %%
X_new.columns
# Out:
# Index(['no_of_dependents', 'cibil_score', 'loan_term', 'education_ Graduate',
#        'self_employed_ Yes', 'income', 'loan_amt'],
#       dtype='object')

# %%
X_new
# Out:
#       no_of_dependents  cibil_score  loan_term  education_ Graduate  \
# 0                    2          778         12                    1
# 1                    0          417          8                    0
# 2                    3          506         20                    1
# 3                    3          467          8                    1
# 4                    5          382         20                    0
# ...                ...          ...        ...                  ...
# 4264                 5          317         12                    1
# 4265                 0          559         20                    0
# 4266                 2          457         18                    0
# 4267                 1          780          8                    0
# 4268                 1          607         10                    1
#
#       self_employed_ Yes    income  loan_amt
# 0                      0  0.969072  0.755102
# 1                      1  0.402062  0.303571
# 2                      0  0.917526  0.750000
# 3                      0  0.824742  0.775510
# 4                      1  0.989691  0.609694
# ...                  ...       ...       ...
# 4264                   1  0.082474  0.051020
# 4265                   1  0.319588  0.280612
# 4266                   0  0.649485  0.602041
# 4267                   0  0.402062  0.318878
# 4268                   0  0.927835  0.750000
#
# [4269 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X_new,y,random_state=0, test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9756554307116105

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       409
#            1       0.98      0.98      0.98       659
#
#     accuracy                           0.98      1068
#    macro avg       0.97      0.97      0.97      1068
# weighted avg       0.98      0.98      0.98      1068

# %%
X_test
# Out:
#       no_of_dependents  cibil_score  loan_term  education_ Graduate  \
# 1972                 1          673         10                    1
# 528                  2          559          4                    1
# 3540                 1          551          8                    1
# 87                   1          402          8                    0
# 1621                 0          362          2                    0
# ...                ...          ...        ...                  ...
# 3914                 5          360          6                    0
# 2174                 5          406          6                    1
# 899                  4          841          2                    0
# 386                  5          302         16                    0
# 3370                 5          760         10                    1
#
#       self_employed_ Yes    income  loan_amt
# 1972                   1  0.835052  0.443878
# 528                    1  0.721649  0.602041
# 3540                   0  0.793814  0.395408
# 87                     1  0.876289  0.714286
# 1621                   1  0.721649  0.390306
# ...                  ...       ...       ...
# 3914                   0  0.618557  0.410714
# 2174                   1  0.639175  0.602041
# 899                    0  0.268041  0.267857
# 386                    1  0.948454  0.892857
# 3370                   1  0.329897  0.318878
#
# [1068 rows x 7 columns]

# %%
y_test
# Out:
# 1972    1
# 528     1
# 3540    1
# 87      0
# 1621    0
#        ..
# 3914    0
# 2174    0
# 899     1
# 386     0
# 3370    1
# Name: loan_status_ Approved, Length: 1068, dtype: int64

# %%
X_n = np.array([
    [1,673,10,1,1,0.835052,0.443878],

])

# %%
y_new_pred = model.predict(X_n)
print(f'Predictions on new data: {y_new_pred}')
# Out:
# Predictions on new data: [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
y_train_pred = model.predict(X_train)

# %%
accuracy_score(y_train,y_train_pred)
# Out:
# 0.9993751952514839

# %%
import joblib

# %%
joblib.dump(model, 'loan_prediction.joblib')
# Out:
# ['loan_prediction.joblib']
